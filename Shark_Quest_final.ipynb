# %%
import pandas as pd
import os

# %%
df = pd.read_excel("https://www.sharkattackfile.net/spreadsheets/GSAF5.xls")

# %%
run Shark_Quest_cleaning.py

# %%
to_use.nunique()
# Out:
# year        25
# type         2
# country     51
# state      152
# injury       6
# species     19
# dtype: int64

# %%
to_use
# Out:
#       year        type       country                  state          injury  \
# 2647  2000    Provoked     AUSTRALIA        New South Wales     lacerations
# 2648  2000  Unprovoked       OKINAWA          Miyako Island           fatal
# 2654  2000  Unprovoked  SOUTH AFRICA  Western Cape Province  minor injuries
# 2657  2000  Unprovoked       REUNION           Saint-Pierre  minor injuries
# 2660  2000  Unprovoked           USA                Florida           fatal
# ...    ...         ...           ...                    ...             ...
# 31    2024  Unprovoked     AUSTRALIA       New  South Wales  minor injuries
# 29    2024  Unprovoked         INDIA            Maharashtra  minor injuries
# 28    2024  Unprovoked     AUSTRALIA      Western Australia  minor injuries
# 26    2024  Unprovoked           USA                 Hawaii       no injury
# 25    2024  Unprovoked     AUSTRALIA             Queensland  minor injuries
#
#           species
# 2647   blue shark
# ...

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.barplot(x="Attack_Count", y="Country", data= top_countries)
plt.title('Number of Shark Attacks by Country')
plt.xlabel('Number of Attacks')
plt.ylabel('Country')
# Out:
# Text(0, 0.5, 'Country')

# %%
plt.figure(figsize=(9, 6))
sns.barplot(x="Species", y="Unprovoked_Attacks", data= top_species)
plt.title('Number of Unprovoked Shark Attacks by Species')
plt.xlabel('Species')
plt.ylabel('Number of Unprovoked Attacks')
plt.xticks(rotation=45, ha="right")
plt.tight_layout()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='country', y='count', hue='state', data=top_10_attacks_state)
plt.title('Top 10 States with most attacks in most affected countries')
plt.xlabel('Country')
plt.ylabel('Unprovoked Attacks')
plt.show()

# %%
plt.figure(figsize=(9, 6))
sns.barplot(x="Species", y="Attack_Count", data= top_state_shark)
plt.title("Shark Species in North Carolina")
plt.xlabel('Species')
plt.ylabel('Number of Unprovoked Attacks')
# Out:
# Text(0, 0.5, 'Number of Unprovoked Attacks')
